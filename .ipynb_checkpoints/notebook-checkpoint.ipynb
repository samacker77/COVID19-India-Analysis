# %% [markdown]
# # COVID19-India-Analysis [Kaggle Notebook](https://www.kaggle.com/samacker77k/covid19-india-analysis)
# A notebook dedicated to data visualization and analysis of COVID19 Pandemic in India.
#
# ---
#
# This notebook visualizes the effects of COVID19 pandemic in India to help understand the effect of the outbreak demographically.
#
# Maintained by:
# * Shivani Tyagi [LinkedIn](https://www.linkedin.com/in/shivani-tyagi-09/) [Github](https://github.com/shivitg)
# * Nitika Kamboj [LinkedIn](https://linkedin.com/in/nitika-kamboj) [Github](https://github.com/nitika-kamboj)
# * Samar Srivastava [LinkedIn](https://linkedin.com/in/samacker77l) [Github](https://github.com/samacker77)

# %% [markdown]
# ---

# %% [markdown]
# ### Fetching Data
# ---

# %%
import requests
import pandas as pd
import logging
import datetime

# %% [markdown]
# ### Enable logging

# %%
loggers = {}

def get_logger(name):
    
    global loggers

    if loggers.get(name):
        return loggers.get(name)
    else:
        logger = logging.getLogger(name)
        logger.setLevel(logging.DEBUG)
        now = datetime.datetime.now()
        handler = logging.StreamHandler()
        formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
        handler.setFormatter(formatter)
        logger.addHandler(handler)
        loggers[name] = logger
        return logger
    
logger = get_logger('COVID19 India Analysis Logger')

# %%
def fetch_data():
    url = 'http://portal.covid19india.org/export?_export=json'
    response = requests.get(url=url)
    if response.status_code == 200:
        logger.info('Connection enabled. Fetching data...')
        fetched_data = response.json()
        data = pd.DataFrame(fetched_data)
        print("Data fetched.")
        return data
    else:
        print('Connection failed. Please retry.')
        return

# %%
data = fetch_data()
# Out:
# 2020-03-24 14:20:05,020 INFO Connection enabled. Fetching data...
# 2020-03-24 14:20:05,020 INFO Connection enabled. Fetching data...
# Data fetched.

# %% [markdown]
# ---
# #### Now we have fetched data successfully. Now we will inspect the data.

# %%
print("Data Shape ~ Rows = {} | Columns = {}".format(data.shape[0],data.shape[1]))
# Out:
# Data Shape ~ Rows = 504 | Columns = 19

# %% [markdown]
# #### Checking dtypes

# %%
data.dtypes
# Out:
# ID                       int64
# Unique id               object
# Government id           object
# Diagnosed date          object
# Age                    float64
# Gender                  object
# Detected city           object
# Detected city pt        object
# Detected district       object
# Detected state          object
# Nationality             object
# Current status          object
# Status change date      object
# Notes                   object
# Current location        object
# Current location pt     object
# Created on              object
# Updated on              object
# Contacts                object
# dtype: object

# %% [markdown]
# > On first look we see that the attributes 'ID' and 'Unique ID' are same. So we check if they have any values that are different. Before that we convert 'Unique ID' to int64 and compare.

# %%
data['Unique id'] = data['Unique id'].astype('int64')

# %%
data[data['ID'] == data['Unique id']]
# Out:
#       ID  Unique id Government id Diagnosed date   Age   Gender  \
# 0      1          1      KL-TS-P1    30/Jan/2020  20.0   Female
# 1      2          2      KL-AL-P1    02/Feb/2020   NaN  Unknown
# 2      3          3      KL-KS-P1    03/Feb/2020   NaN  Unknown
# 3      4          4         DL-P1    02/Mar/2020  45.0     Male
# 4      5          5         TS-P1    02/Mar/2020   NaN  Unknown
# ..   ...        ...           ...            ...   ...      ...
# 499  500        500          None    23/Mar/2020  25.0     Male
# 500  501        501          None    23/Mar/2020  48.0     Male
# 501  502        502          None    23/Mar/2020  54.0     Male
# 502  503        503          None    23/Mar/2020  24.0     Male
# 503  504        504          None    23/Mar/2020  35.0     Male
#
#                 Detected city  \
# 0                    Thrissur
# 1                   Alappuzha
# 2                   Kasargode
# 3    East Delhi (Mayur Vihar)
# 4                   Hyderabad
# ..                        ...
# 499                   Chennai
# 500                  Tiruppur
# 501                   Madurai
# 502                      None
# 503                   Jaunpur
#
#                                       Detected city pt Detected district  \
# 0       SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
# 1        SRID=4326;POINT (76.333482 9.498000100000001)         Alappuzha
# 2                              SRID=4326;POINT (80 20)         Kasaragod
# 3                              SRID=4326;POINT (80 20)        East Delhi
# 4        SRID=4326;POINT (78.4349398685041 17.4263524)         Hyderabad
# ..                                                 ...               ...
# 499            SRID=4326;POINT (80.2838331 13.0801721)           Chennai
# 500    SRID=4326;POINT (77.52604780096844 10.78322705)          Tiruppur
# 501  SRID=4326;POINT (78.11409829999999 9.926115299...           Madurai
# 502             SRID=4326;POINT (85.906508 25.6440845)             Patna
# 503     SRID=4326;POINT (82.48834097504385 25.7955927)          Varanasi
#
#     Detected state Nationality Current status Status change date  \
# 0           Kerala       India      Recovered         02/14/2020
# 1           Kerala       India      Recovered         02/14/2020
# 2           Kerala       India      Recovered         02/14/2020
# 3            Delhi       India      Recovered         03/15/2020
# 4        Telangana       India      Recovered         03/02/2020
# ..             ...         ...            ...                ...
# 499     Tamil Nadu        None   Hospitalized         02/23/2020
# 500     Tamil Nadu        None   Hospitalized         02/23/2020
# 501     Tamil Nadu        None   Hospitalized         02/23/2020
# 502          Bihar        None   Hospitalized         02/23/2020
# 503  Uttar Pradesh        None   Hospitalized         02/23/2020
#
#                                                  Notes Current location  \
# 0            Travelled from Wuhan.\nStudent from Wuhan             None
# 1            Travelled from Wuhan.\nStudent from Wuhan             None
# 2            Travelled from Wuhan.\nStudent from Wuhan             None
# 3    Travelled from Austria, Italy.\nTravel history...             None
# 4    Travelled from Dubai, Singapore contact.\nTrav...             None
# ..                                                 ...              ...
# 499                       Travelled from London - RGGH             None
# 500                        Travelled from London - ESI             None
# 501  Annanagar at Rajaji Hosp. No mention of travel...             None
# 502                            Travelled from Scotland             None
# 503  Travelled from Saudi Arabia on 15th Mar; Sympt...             None
#
#                                    Current location pt             Created on  \
# 0       SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
# 1        SRID=4326;POINT (76.333482 9.498000100000001)  03/23/2020 12:20 p.m.
# 2                              SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 3                              SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 4        SRID=4326;POINT (78.4349398685041 17.4263524)  03/23/2020 12:20 p.m.
# ..                                                 ...                    ...
# 499            SRID=4326;POINT (80.2838331 13.0801721)   03/24/2020 8:15 a.m.
# 500    SRID=4326;POINT (77.52604780096844 10.78322705)   03/24/2020 8:15 a.m.
# 501  SRID=4326;POINT (78.11409829999999 9.926115299...   03/24/2020 8:15 a.m.
# 502             SRID=4326;POINT (85.906508 25.6440845)   03/24/2020 8:15 a.m.
# 503     SRID=4326;POINT (82.48834097504385 25.7955927)   03/24/2020 8:15 a.m.
#
#                 Updated on                                           Contacts
# 0    03/23/2020 12:20 p.m.                                               None
# 1    03/23/2020 12:20 p.m.                                               None
# 2    03/23/2020 12:20 p.m.                                               None
# 3    03/23/2020 12:20 p.m.  Patient 22:, Patient 23:, Patient 24:, Patient...
# 4    03/23/2020 12:20 p.m.                                               None
# ..                     ...                                                ...
# 499   03/24/2020 8:15 a.m.                                               None
# 500   03/24/2020 8:15 a.m.                                               None
# 501   03/24/2020 8:15 a.m.                                               None
# 502   03/24/2020 8:15 a.m.                                               None
# 503   03/24/2020 8:15 a.m.                                               None
#
# [504 rows x 19 columns]

# %% [markdown]
# > Since we have same values in both columns. We can drop one of them and make another as the index

# %%
data.drop('Unique id',axis=1,inplace=True)

# %%
data.set_index('ID',inplace=True)

# %%
# Out:
#       ID Government id Diagnosed date   Age   Gender  \
# 0      1      KL-TS-P1    30/Jan/2020  20.0   Female
# 1      2      KL-AL-P1    02/Feb/2020   NaN  Unknown
# 2      3      KL-KS-P1    03/Feb/2020   NaN  Unknown
# 3      4         DL-P1    02/Mar/2020  45.0     Male
# 4      5         TS-P1    02/Mar/2020   NaN  Unknown
# ..   ...           ...            ...   ...      ...
# 499  500          None    23/Mar/2020  25.0     Male
# 500  501          None    23/Mar/2020  48.0     Male
# 501  502          None    23/Mar/2020  54.0     Male
# 502  503          None    23/Mar/2020  24.0     Male
# 503  504          None    23/Mar/2020  35.0     Male
#
#                 Detected city  \
# 0                    Thrissur
# 1                   Alappuzha
# 2                   Kasargode
# 3    East Delhi (Mayur Vihar)
# 4                   Hyderabad
# ..                        ...
# 499                   Chennai
# 500                  Tiruppur
# 501                   Madurai
# 502                      None
# 503                   Jaunpur
#
#                                       Detected city pt Detected district  \
# 0       SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
# 1        SRID=4326;POINT (76.333482 9.498000100000001)         Alappuzha
# 2                              SRID=4326;POINT (80 20)         Kasaragod
# 3                              SRID=4326;POINT (80 20)        East Delhi
# 4        SRID=4326;POINT (78.4349398685041 17.4263524)         Hyderabad
# ..                                                 ...               ...
# 499            SRID=4326;POINT (80.2838331 13.0801721)           Chennai
# 500    SRID=4326;POINT (77.52604780096844 10.78322705)          Tiruppur
# 501  SRID=4326;POINT (78.11409829999999 9.926115299...           Madurai
# 502             SRID=4326;POINT (85.906508 25.6440845)             Patna
# 503     SRID=4326;POINT (82.48834097504385 25.7955927)          Varanasi
#
#     Detected state Nationality Current status Status change date  \
# 0           Kerala       India      Recovered         02/14/2020
# 1           Kerala       India      Recovered         02/14/2020
# 2           Kerala       India      Recovered         02/14/2020
# 3            Delhi       India      Recovered         03/15/2020
# 4        Telangana       India      Recovered         03/02/2020
# ..             ...         ...            ...                ...
# 499     Tamil Nadu        None   Hospitalized         02/23/2020
# 500     Tamil Nadu        None   Hospitalized         02/23/2020
# 501     Tamil Nadu        None   Hospitalized         02/23/2020
# 502          Bihar        None   Hospitalized         02/23/2020
# 503  Uttar Pradesh        None   Hospitalized         02/23/2020
#
#                                                  Notes Current location  \
# 0            Travelled from Wuhan.\nStudent from Wuhan             None
# 1            Travelled from Wuhan.\nStudent from Wuhan             None
# 2            Travelled from Wuhan.\nStudent from Wuhan             None
# 3    Travelled from Austria, Italy.\nTravel history...             None
# 4    Travelled from Dubai, Singapore contact.\nTrav...             None
# ..                                                 ...              ...
# 499                       Travelled from London - RGGH             None
# 500                        Travelled from London - ESI             None
# 501  Annanagar at Rajaji Hosp. No mention of travel...             None
# 502                            Travelled from Scotland             None
# 503  Travelled from Saudi Arabia on 15th Mar; Sympt...             None
#
#                                    Current location pt             Created on  \
# 0       SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
# 1        SRID=4326;POINT (76.333482 9.498000100000001)  03/23/2020 12:20 p.m.
# 2                              SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 3                              SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 4        SRID=4326;POINT (78.4349398685041 17.4263524)  03/23/2020 12:20 p.m.
# ..                                                 ...                    ...
# 499            SRID=4326;POINT (80.2838331 13.0801721)   03/24/2020 8:15 a.m.
# 500    SRID=4326;POINT (77.52604780096844 10.78322705)   03/24/2020 8:15 a.m.
# 501  SRID=4326;POINT (78.11409829999999 9.926115299...   03/24/2020 8:15 a.m.
# 502             SRID=4326;POINT (85.906508 25.6440845)   03/24/2020 8:15 a.m.
# 503     SRID=4326;POINT (82.48834097504385 25.7955927)   03/24/2020 8:15 a.m.
#
#                 Updated on                                           Contacts
# 0    03/23/2020 12:20 p.m.                                               None
# 1    03/23/2020 12:20 p.m.                                               None
# 2    03/23/2020 12:20 p.m.                                               None
# 3    03/23/2020 12:20 p.m.  Patient 22:, Patient 23:, Patient 24:, Patient...
# 4    03/23/2020 12:20 p.m.                                               None
# ..                     ...                                                ...
# 499   03/24/2020 8:15 a.m.                                               None
# 500   03/24/2020 8:15 a.m.                                               None
# 501   03/24/2020 8:15 a.m.                                               None
# 502   03/24/2020 8:15 a.m.                                               None
# 503   03/24/2020 8:15 a.m.                                               None
#
# [504 rows x 18 columns]

# %%
print("Data Shape ~ Rows = {} | Columns = {}".format(data.shape[0],data.shape[1]))
# Out:
# Data Shape ~ Rows = 504 | Columns = 17

# %%
data.head()
# Out:
#    Government id Diagnosed date   Age   Gender             Detected city  \
# ID
# 1       KL-TS-P1    30/Jan/2020  20.0   Female                  Thrissur
# 2       KL-AL-P1    02/Feb/2020   NaN  Unknown                 Alappuzha
# 3       KL-KS-P1    03/Feb/2020   NaN  Unknown                 Kasargode
# 4          DL-P1    02/Mar/2020  45.0     Male  East Delhi (Mayur Vihar)
# 5          TS-P1    02/Mar/2020   NaN  Unknown                 Hyderabad
#
#                                   Detected city pt Detected district  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
# 2    SRID=4326;POINT (76.333482 9.498000100000001)         Alappuzha
# 3                          SRID=4326;POINT (80 20)         Kasaragod
# 4                          SRID=4326;POINT (80 20)        East Delhi
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)         Hyderabad
#
#    Detected state Nationality Current status Status change date  \
# ID
# 1          Kerala       India      Recovered         02/14/2020
# 2          Kerala       India      Recovered         02/14/2020
# 3          Kerala       India      Recovered         02/14/2020
# 4           Delhi       India      Recovered         03/15/2020
# 5       Telangana       India      Recovered         03/02/2020
#
#                                                 Notes Current location  \
# ID
# 1           Travelled from Wuhan.\nStudent from Wuhan             None
# 2           Travelled from Wuhan.\nStudent from Wuhan             None
# 3           Travelled from Wuhan.\nStudent from Wuhan             None
# 4   Travelled from Austria, Italy.\nTravel history...             None
# 5   Travelled from Dubai, Singapore contact.\nTrav...             None
#
#                                Current location pt             Created on  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
# 2    SRID=4326;POINT (76.333482 9.498000100000001)  03/23/2020 12:20 p.m.
# 3                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 4                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)  03/23/2020 12:20 p.m.
#
#                Updated on                                           Contacts
# ID
# 1   03/23/2020 12:20 p.m.                                               None
# 2   03/23/2020 12:20 p.m.                                               None
# 3   03/23/2020 12:20 p.m.                                               None
# 4   03/23/2020 12:20 p.m.  Patient 22:, Patient 23:, Patient 24:, Patient...
# 5   03/23/2020 12:20 p.m.                                               None

# %% [markdown]
# #### Now the data is ready for analysis and preprocessing

# %% [markdown]
# ---
