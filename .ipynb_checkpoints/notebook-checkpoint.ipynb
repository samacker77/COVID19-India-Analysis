# %% [markdown]
# # COVID19-India-Analysis [Kaggle Notebook](https://www.kaggle.com/samacker77k/covid19-india-analysis)
# A notebook dedicated to data visualization and analysis of COVID19 Pandemic in India.
#
# ---
#
# This notebook visualizes the effects of COVID19 pandemic in India to help understand the effect of the outbreak demographically.
#
# Maintained by:
# * Shivani Tyagi [LinkedIn](https://www.linkedin.com/in/shivani-tyagi-09/) [Github](https://github.com/shivitg)
# * Nitika Kamboj [LinkedIn](https://linkedin.com/in/nitika-kamboj) [Github](https://github.com/nitika-kamboj)
# * Samar Srivastava [LinkedIn](https://linkedin.com/in/samacker77l) [Github](https://github.com/samacker77)

# %% [markdown]
# ---

# %% [markdown]
# ### Fetching Data
# ---

# %%
import requests
import pandas as pd
import logging
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set(font_scale=1.4)

# %% [markdown]
# ### Enable logging

# %%
loggers = {}

def get_logger(name):
    
    global loggers

    if loggers.get(name):
        return loggers.get(name)
    else:
        logger = logging.getLogger(name)
        logger.setLevel(logging.DEBUG)
        now = datetime.datetime.now()
        handler = logging.StreamHandler()
        formatter = logging.Formatter('%(asctime)s %(levelname)s %(message)s')
        handler.setFormatter(formatter)
        logger.addHandler(handler)
        loggers[name] = logger
        return logger
    
logger = get_logger('COVID19 India Analysis Logger')

# %%
def fetch_data():
    url = 'http://portal.covid19india.org/export?_export=json'
    response = requests.get(url=url)
    if response.status_code == 200:
        logger.info('Connection enabled. Fetching data...')
        fetched_data = response.json()
        data = pd.DataFrame(fetched_data)
        print("Data fetched.")
        return data
    else:
        print('Connection failed. Please retry.')
        return

# %%
data = fetch_data()
# Out:
# 2020-03-24 15:07:18,598 INFO Connection enabled. Fetching data...
# Data fetched.

# %% [markdown]
# ---
# #### Now we have fetched data successfully. Now we will inspect the data.

# %%
print("Data Shape ~ Rows = {} | Columns = {}".format(data.shape[0],data.shape[1]))
# Out:
# Data Shape ~ Rows = 504 | Columns = 19

# %% [markdown]
# #### Checking dtypes

# %%
data.dtypes
# Out:
# Age                    float64
# Contacts                object
# Created on              object
# Current location        object
# Current location pt     object
# Current status          object
# Detected city           object
# Detected city pt        object
# Detected district       object
# Detected state          object
# Diagnosed date          object
# Gender                  object
# Government id           object
# ID                       int64
# Nationality             object
# Notes                   object
# Status change date      object
# Unique id               object
# Updated on              object
# dtype: object

# %% [markdown]
# > On first look we see that the attributes 'ID' and 'Unique ID' are same. So we check if they have any values that are different. Before that we convert 'Unique ID' to int64 and compare.

# %%
data['Unique id'] = data['Unique id'].astype('int64')

# %%
data[data['ID'] == data['Unique id']]
# Out:
#       Age                                           Contacts  \
# 0    20.0                                               None
# 1     NaN                                               None
# 2     NaN                                               None
# 3    45.0  Patient 22:, Patient 23:, Patient 24:, Patient...
# 4     NaN                                               None
# 5    69.0  Patient 7:, Patient 8:, Patient 9:, Patient 10...
# 6    55.0                                         Patient 6:
# 7    55.0                                         Patient 6:
# 8    55.0                                         Patient 6:
# 9    55.0                                         Patient 6:
# 10   55.0                                         Patient 6:
# 11   55.0                                         Patient 6:
# 12   55.0                                         Patient 6:
# 13   55.0                                         Patient 6:
# 14   55.0                                         Patient 6:
# 15   55.0                                         Patient 6:
# 16   55.0                                         Patient 6:
# 17   55.0                                         Patient 6:
# 18   55.0                                         Patient 6:
# 19   55.0                                         Patient 6:
# 20   70.0                                         Patient 6:
# 21    NaN                       Patient 4:DL-P1, Patient 48:
# 22    NaN                                    Patient 4:DL-P1
# 23    NaN                                    Patient 4:DL-P1
# 24    NaN                                    Patient 4:DL-P1
# 25    NaN                                    Patient 4:DL-P1
# 26    NaN                                    Patient 4:DL-P1
# 27    NaN                                         Patient 6:
# 28   27.0                                   Patient 40:DL-P4
# 29   59.0                                        Patient 82:
# ..    ...                                                ...
# 474  60.0                                               None
# 475  22.0                                               None
# 476  38.0                                               None
# 477   NaN                                               None
# 478   NaN                                               None
# 479   NaN                                               None
# 480   NaN                                               None
# 481   NaN                                               None
# 482   NaN                                               None
# 483  45.0                                               None
# 484   NaN                                               None
# 485  45.0                                               None
# 486  69.0                                               None
# 487   2.0                                  Patient 182:PJ-P2
# 488   NaN                                               None
# 489   NaN                                               None
# 490   NaN                                               None
# 491   NaN                                               None
# 492  25.0                                               None
# 493   NaN                                               None
# 494   NaN                                               None
# 495   NaN                                               None
# 496   NaN                                               None
# 497   NaN                                               None
# 498   NaN                                               None
# 499  25.0                                               None
# 500  48.0                                               None
# 501  54.0                                               None
# 502  24.0                                               None
# 503  35.0                                               None
#
#                 Created on Current location  \
# 0    03/23/2020 12:20 p.m.             None
# 1    03/23/2020 12:20 p.m.             None
# 2    03/23/2020 12:20 p.m.             None
# 3    03/23/2020 12:20 p.m.             None
# 4    03/23/2020 12:20 p.m.             None
# 5    03/23/2020 12:20 p.m.             None
# 6    03/23/2020 12:20 p.m.             None
# 7    03/23/2020 12:20 p.m.             None
# 8    03/23/2020 12:20 p.m.             None
# 9    03/23/2020 12:20 p.m.             None
# 10   03/23/2020 12:20 p.m.             None
# 11   03/23/2020 12:20 p.m.             None
# 12   03/23/2020 12:20 p.m.             None
# 13   03/23/2020 12:20 p.m.             None
# 14   03/23/2020 12:20 p.m.             None
# 15   03/23/2020 12:20 p.m.             None
# 16   03/23/2020 12:20 p.m.             None
# 17   03/23/2020 12:20 p.m.             None
# 18   03/23/2020 12:20 p.m.             None
# 19   03/23/2020 12:20 p.m.             None
# 20   03/23/2020 12:20 p.m.             None
# 21   03/23/2020 12:20 p.m.             None
# 22   03/23/2020 12:20 p.m.             None
# 23   03/23/2020 12:20 p.m.             None
# 24   03/23/2020 12:20 p.m.             None
# 25   03/23/2020 12:20 p.m.             None
# 26   03/23/2020 12:20 p.m.             None
# 27   03/23/2020 12:20 p.m.             None
# 28   03/23/2020 12:20 p.m.             None
# 29   03/23/2020 12:20 p.m.             None
# ..                     ...              ...
# 474   03/24/2020 8:15 a.m.             None
# 475   03/24/2020 8:15 a.m.             None
# 25      SRID=4326;POINT (78.00981609999999 27.1752554)   Hospitalized
# 26      SRID=4326;POINT (78.00981609999999 27.1752554)   Hospitalized
# 27              SRID=4326;POINT (80.859666 27.1303344)   Hospitalized
# 28             SRID=4326;POINT (77.0874757 28.6219272)   Hospitalized
# 29             SRID=4326;POINT (77.4120356 28.6711527)      Recovered
# ..                                                 ...            ...
# 474     SRID=4326;POINT (77.59129969999999 12.9791198)   Hospitalized
# 475     SRID=4326;POINT (77.59129969999999 12.9791198)   Hospitalized
# 476            SRID=4326;POINT (72.8353355 18.9387711)   Hospitalized
# 477            SRID=4326;POINT (72.8353355 18.9387711)   Hospitalized
# 478            SRID=4326;POINT (72.9701779 19.1943294)   Hospitalized
# 479            SRID=4326;POINT (74.5948885 16.8502534)   Hospitalized
# 480            SRID=4326;POINT (74.5948885 16.8502534)   Hospitalized
# 481            SRID=4326;POINT (74.5948885 16.8502534)   Hospitalized
# 482            SRID=4326;POINT (74.5948885 16.8502534)   Hospitalized
# 483    SRID=4326;POINT (74.04109989149464 18.06547435)   Hospitalized
# 484      SRID=4326;POINT (81.207643234204 26.92228995)   Hospitalized
# 485    SRID=4326;POINT (80.10754080018077 28.49520765)   Hospitalized
# 486                  SRID=4326;POINT (76.25 32.166667)       Deceased
# 487     SRID=4326;POINT (75.50048409999999 30.9293211)   Hospitalized
# 488     SRID=4326;POINT (75.50048409999999 30.9293211)   Hospitalized
# 489     SRID=4326;POINT (73.76845489999999 26.8105777)   Hospitalized
# 490     SRID=4326;POINT (73.76845489999999 26.8105777)   Hospitalized
# 491     SRID=4326;POINT (73.76845489999999 26.8105777)   Hospitalized
# 492                            SRID=4326;POINT (80 20)   Hospitalized
# 493                            SRID=4326;POINT (76 29)   Hospitalized
# 494                            SRID=4326;POINT (76 29)   Hospitalized
# 495                            SRID=4326;POINT (76 29)   Hospitalized
# 496                            SRID=4326;POINT (76 29)   Hospitalized
# 497                            SRID=4326;POINT (76 29)   Hospitalized
# 498                            SRID=4326;POINT (76 29)   Hospitalized
# 499            SRID=4326;POINT (80.2838331 13.0801721)   Hospitalized
# 500    SRID=4326;POINT (77.52604780096844 10.78322705)   Hospitalized
# 501  SRID=4326;POINT (78.11409829999999 9.926115299...   Hospitalized
# 502             SRID=4326;POINT (85.906508 25.6440845)   Hospitalized
# 503     SRID=4326;POINT (82.48834097504385 25.7955927)   Hospitalized
#
#                 Detected city  \
# 0                    Thrissur
# 1                   Alappuzha
# 2                   Kasargode
# 3    East Delhi (Mayur Vihar)
# 4                   Hyderabad
# 5                      Jaipur
# 6                    Gurugram
# 7                    Gurugram
# 8                    Gurugram
# 9                    Gurugram
# 10                   Gurugram
# 11                   Gurugram
# 12                   Gurugram
# 13                   Gurugram
# 14                   Gurugram
# 15                   Gurugram
# 16                   Gurugram
# 17                   Gurugram
# 18                   Gurugram
# 19                   Gurugram
# 20                     Jaipur
# 21                       Agra
# 483    SRID=4326;POINT (74.04109989149464 18.06547435)
# 484      SRID=4326;POINT (81.207643234204 26.92228995)
# 485    SRID=4326;POINT (80.10754080018077 28.49520765)
# 486                  SRID=4326;POINT (76.25 32.166667)
# 487     SRID=4326;POINT (75.50048409999999 30.9293211)
# 488     SRID=4326;POINT (75.50048409999999 30.9293211)
# 489     SRID=4326;POINT (73.76845489999999 26.8105777)
# 490     SRID=4326;POINT (73.76845489999999 26.8105777)
# 491     SRID=4326;POINT (73.76845489999999 26.8105777)
# 492                            SRID=4326;POINT (80 20)
# 493                            SRID=4326;POINT (76 29)
# 494                            SRID=4326;POINT (76 29)
# 495                            SRID=4326;POINT (76 29)
# 496                            SRID=4326;POINT (76 29)
# 497                            SRID=4326;POINT (76 29)
# 498                            SRID=4326;POINT (76 29)
# 499            SRID=4326;POINT (80.2838331 13.0801721)
# 500    SRID=4326;POINT (77.52604780096844 10.78322705)
# 501  SRID=4326;POINT (78.11409829999999 9.926115299...
# 502             SRID=4326;POINT (85.906508 25.6440845)
# 503     SRID=4326;POINT (82.48834097504385 25.7955927)
#
#               Detected district    Detected state Diagnosed date   Gender  \
# 0                      Thrissur            Kerala    30/Jan/2020   Female
# 1                     Alappuzha            Kerala    02/Feb/2020  Unknown
# 2                     Kasaragod            Kerala    03/Feb/2020  Unknown
# 3                    East Delhi             Delhi    02/Mar/2020     Male
# 4                     Hyderabad         Telangana    02/Mar/2020  Unknown
# 5                        Jaipur         Rajasthan    03/Mar/2020     Male
# 6                      Gurugram           Haryana    04/Mar/2020  Unknown
# 7                      Gurugram           Haryana    04/Mar/2020  Unknown
# 8                      Gurugram           Haryana    04/Mar/2020  Unknown
# 9                      Gurugram           Haryana    04/Mar/2020  Unknown
# 10                     Gurugram           Haryana    04/Mar/2020  Unknown
# 11                     Gurugram           Haryana    04/Mar/2020  Unknown
# 12                     Gurugram           Haryana    04/Mar/2020  Unknown
# 13                     Gurugram           Haryana    04/Mar/2020  Unknown
# 14                     Gurugram           Haryana    04/Mar/2020  Unknown
# 15                     Gurugram           Haryana    04/Mar/2020  Unknown
# 16                     Gurugram           Haryana    04/Mar/2020  Unknown
# 17                     Gurugram           Haryana    04/Mar/2020  Unknown
# 18                     Gurugram           Haryana    04/Mar/2020  Unknown
# 19                     Gurugram           Haryana    04/Mar/2020  Unknown
# 20                       Jaipur         Rajasthan    04/Mar/2020   Female
# 21                         Agra     Uttar Pradesh    04/Mar/2020  Unknown
# 22                         Agra     Uttar Pradesh    04/Mar/2020  Unknown
# 23                         Agra     Uttar Pradesh    04/Mar/2020  Unknown
# 24                         Agra     Uttar Pradesh    04/Mar/2020  Unknown
# 25                         Agra     Uttar Pradesh    04/Mar/2020  Unknown
# 26                         Agra     Uttar Pradesh    04/Mar/2020  Unknown
# 27                         None     Uttar Pradesh    04/Mar/2020  Unknown
# 28                         None             Delhi    05/Mar/2020     Male
# 29                    Ghaziabad     Uttar Pradesh    05/Mar/2020     Male
# ..                          ...               ...            ...      ...
# 474                   Bengaluru         Karnataka    23/Mar/2020     Male
# 475                   Bengaluru         Karnataka    23/Mar/2020     Male
# 476                        None       Maharashtra    23/Mar/2020   Female
# 477                        None       Maharashtra    23/Mar/2020  Unknown
# 478                       Thane       Maharashtra    23/Mar/2020  Unknown
# 479                        None       Maharashtra    23/Mar/2020     Male
# 480                        None       Maharashtra    23/Mar/2020   Female
# 481                        None       Maharashtra    23/Mar/2020   Female
# 482                        None       Maharashtra    23/Mar/2020   Female
# 483                      Satara       Maharashtra    23/Mar/2020   Female
# 484                      Kanpur     Uttar Pradesh    23/Mar/2020  Unknown
# 485                        None     Uttar Pradesh    23/Mar/2020   Female
# 486                      Kangra  Himachal Pradesh    23/Mar/2020     Male
# 487  Shaheed Bhagat Singh Nagar            Punjab    23/Mar/2020     Male
# 488  Sahibzada Ajit Singh Nagar            Punjab    23/Mar/2020  Unknown
# 489                     Jodhpur         Rajasthan    23/Mar/2020  Unknown
# 490                 Pratapgarh          Rajasthan    23/Mar/2020  Unknown
# 491                 Pratapgarh          Rajasthan    23/Mar/2020  Unknown
# 492              Vishakhapatnam    Andhra Pradesh    23/Mar/2020     Male
# 493                        None           Haryana    23/Mar/2020  Unknown
# 494                        None           Haryana    23/Mar/2020  Unknown
# 495                        None           Haryana    23/Mar/2020  Unknown
# 496                        None           Haryana    23/Mar/2020  Unknown
# 497                        None           Haryana    23/Mar/2020  Unknown
# 498                        None           Haryana    23/Mar/2020  Unknown
# 499                     Chennai        Tamil Nadu    23/Mar/2020     Male
# 500                    Tiruppur        Tamil Nadu    23/Mar/2020     Male
# 501                     Madurai        Tamil Nadu    23/Mar/2020     Male
# 502                       Patna             Bihar    23/Mar/2020     Male
# 503                    Varanasi     Uttar Pradesh    23/Mar/2020     Male
#
#     Government id   ID Nationality  \
# 0        KL-TS-P1    1       India
# 1        KL-AL-P1    2       India
# 2        KL-KS-P1    3       India
# 3           DL-P1    4       India
# 4           TS-P1    5       India
# 5            None    6       Italy
# 6            None    7       Italy
# 7            None    8       Italy
# 8            None    9       Italy
# 9            None   10       Italy
# 10           None   11       Italy
# 11           None   12       Italy
# 12           None   13       Italy
# 13           None   14       Italy
# 14           None   15       Italy
# 15           None   16       Italy
# 16           None   17       Italy
# 17           None   18       Italy
# 18           None   19       Italy
# 19           None   20       Italy
# 20           None   21       Italy
# 21           None   22       India
# 22           None   23       India
# 23           None   24       India
# 24           None   25       India
# 25           None   26       India
# 26           None   27       India
# 27           None   28       India
# 28          DL-P2   29       India
# 29           None   30       India
# ..            ...  ...         ...
# 474        KA-P32  475        None
# 475        KA-P33  476        None
# 476          None  477        None
# 477          None  478        None
# 478          None  479        None
# 479          None  480        None
# 480          None  481        None
# 481          None  482        None
# 482          None  483        None
# 483          None  484        None
# 484          None  485        None
# 485          None  486        None
# 486          None  487        None
# 487          None  488      Indian
# 488          None  489      Indian
# 489          None  490        None
# 490          None  491        None
# 491          None  492        None
# 492         AP-P7  493        None
# 493          None  494        None
# 494          None  495        None
# 495          None  496        None
# 496          None  497        None
# 497          None  498        None
# 498          None  499        None
# 499          None  500        None
# 500          None  501        None
# 501          None  502        None
# 502          None  503        None
# 503          None  504        None
#
#                                                  Notes Status change date  \
# 0            Travelled from Wuhan.\nStudent from Wuhan         02/14/2020
# 1            Travelled from Wuhan.\nStudent from Wuhan         02/14/2020
# 2            Travelled from Wuhan.\nStudent from Wuhan         02/14/2020
# 3    Travelled from Austria, Italy.\nTravel history...         03/15/2020
# 4    Travelled from Dubai, Singapore contact.\nTrav...         03/02/2020
# 5               Travelled from Italy.\nItalian tourist         03/03/2020
# 6               Travelled from Italy.\nItalian tourist         03/04/2020
# 7               Travelled from Italy.\nItalian tourist         03/04/2020
# 8               Travelled from Italy.\nItalian tourist         03/04/2020
# 9               Travelled from Italy.\nItalian tourist         03/04/2020
# 10              Travelled from Italy.\nItalian tourist         03/04/2020
# 11              Travelled from Italy.\nItalian tourist         03/04/2020
# 12              Travelled from Italy.\nItalian tourist         03/04/2020
# 13              Travelled from Italy.\nItalian tourist         03/04/2020
# 14              Travelled from Italy.\nItalian tourist         03/04/2020
# 15              Travelled from Italy.\nItalian tourist         03/04/2020
# 16              Travelled from Italy.\nItalian tourist         03/04/2020
# 17              Travelled from Italy.\nItalian tourist         03/04/2020
# 18              Travelled from Italy.\nItalian tourist         03/04/2020
# 19              Travelled from Italy.\nItalian tourist         03/04/2020
# 20   Travelled from Italy, Wife of P6.\nItalian tou...         03/04/2020
# 21                                Family members of P4         03/04/2020
# 22                                Family members of P4         03/04/2020
# 23                                Family members of P4         03/04/2020
# 24                                Family members of P4         03/04/2020
# 25                                Family members of P4         03/04/2020
# 26                                Family members of P4         03/04/2020
# 27   Accompanied the Italian tourists, Nationality:...         03/04/2020
# 28   Travelled from Italy PayTm Emp, .\nPayTm Emp, ...         03/05/2020
# 29             Travelled from Iran.\nTravelled to Iran         03/05/2020
# ..                                                 ...                ...
# 474                             Travelled from Germany         02/23/2020
# 475   Travelled from Dubai, resident of Kannur, Kerala         02/23/2020
# 476                          Travelled from Abu Dhabi          02/23/2020
# 477                                    Details awaited         02/23/2020
# 478                 Contact with P 80, Details awaited         02/23/2020
# 479       Travelled from Saudi Arabia, Details awaited         02/23/2020
# 480       Travelled from Saudi Arabia, Details awaited         02/23/2020
# 481       Travelled from Saudi Arabia, Details awaited         02/23/2020
# 482       Travelled from Saudi Arabia, Details awaited         02/23/2020
# 483                          Travelled from Dubai, UAE         02/23/2020
# 484                                 Travelled from USA         02/23/2020
# 485  Travelled from Saudi Arabia.\nTravelled in a g...         02/23/2020
# 486  Tibetan refugee,died at a hospital in Tanda. R...         02/23/2020
# 487                                  Grand son of P182         02/23/2020
# 488  Close contact of Patient (Patient Unknown, lik...         02/23/2020
# 489                                    Details awaited         02/23/2020
# 496        497   03/24/2020 8:15 a.m.
# 497        498   03/24/2020 8:15 a.m.
# 498        499   03/24/2020 8:15 a.m.
# 499        500   03/24/2020 8:15 a.m.
# 500        501   03/24/2020 8:15 a.m.
# 501        502   03/24/2020 8:15 a.m.
# 502        503   03/24/2020 8:15 a.m.
# 503        504   03/24/2020 8:15 a.m.
#
# [504 rows x 19 columns]

# %% [markdown]
# > Since we have same values in both columns. We can drop one of them and make another as the index

# %%
data.drop('Unique id',axis=1,inplace=True)

# %%
data.set_index('ID',inplace=True)

# %%
print("Data Shape ~ Rows = {} | Columns = {}".format(data.shape[0],data.shape[1]))
# Out:
# Data Shape ~ Rows = 504 | Columns = 17

# %%
data.head()
# Out:
#      Age                                           Contacts  \
# ID
# 1   20.0                                               None
# 2    NaN                                               None
# 3    NaN                                               None
# 4   45.0  Patient 22:, Patient 23:, Patient 24:, Patient...
# 5    NaN                                               None
#
#                Created on Current location  \
# ID
# 1   03/23/2020 12:20 p.m.             None
# 2   03/23/2020 12:20 p.m.             None
# 3   03/23/2020 12:20 p.m.             None
# 4   03/23/2020 12:20 p.m.             None
# 5   03/23/2020 12:20 p.m.             None
#
#                                Current location pt Current status  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)      Recovered
# 2    SRID=4326;POINT (76.333482 9.498000100000001)      Recovered
# 3                          SRID=4326;POINT (80 20)      Recovered
# 4                          SRID=4326;POINT (80 20)      Recovered
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)      Recovered
#
#                Detected city                                Detected city pt  \
# ID
# 1                   Thrissur  SRID=4326;POINT (76.21325419999999 10.5256264)
# 2                  Alappuzha   SRID=4326;POINT (76.333482 9.498000100000001)
# 3                  Kasargode                         SRID=4326;POINT (80 20)
# 4   East Delhi (Mayur Vihar)                         SRID=4326;POINT (80 20)
# 5                  Hyderabad   SRID=4326;POINT (78.4349398685041 17.4263524)
#
#    Detected district Detected state Diagnosed date   Gender Government id  \
# ID
# 1           Thrissur         Kerala    30/Jan/2020   Female      KL-TS-P1
# 2          Alappuzha         Kerala    02/Feb/2020  Unknown      KL-AL-P1
# 3          Kasaragod         Kerala    03/Feb/2020  Unknown      KL-KS-P1
# 4         East Delhi          Delhi    02/Mar/2020     Male         DL-P1
# 5          Hyderabad      Telangana    02/Mar/2020  Unknown         TS-P1
#
#    Nationality                                              Notes  \
# ID
# 1        India          Travelled from Wuhan.\nStudent from Wuhan
# 2        India          Travelled from Wuhan.\nStudent from Wuhan
# 3        India          Travelled from Wuhan.\nStudent from Wuhan
# 4        India  Travelled from Austria, Italy.\nTravel history...
# 5        India  Travelled from Dubai, Singapore contact.\nTrav...
#
#    Status change date             Updated on
# ID
# 1          02/14/2020  03/23/2020 12:20 p.m.
# 2          02/14/2020  03/23/2020 12:20 p.m.
# 3          02/14/2020  03/23/2020 12:20 p.m.
# 4          03/15/2020  03/23/2020 12:20 p.m.
# 5          03/02/2020  03/23/2020 12:20 p.m.

# %% [markdown]
# #### Now the data is ready for analysis and preprocessing

# %% [markdown]
# > Graph between the count of affected people and Nationality.

# %%
data['Nationality'].value_counts()
# Out:
# India             307
# Italy              18
# Indonesia          10
# United Kingdom      7
# Indian              2
# Phillipines         2
# Thailand            2
# Canada              1
# Name: Nationality, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(data['Nationality'].value_counts().values,data['Nationality'].value_counts().index, palette=sns.dark_palette("blue", reverse=True))
plt.title('Count of people affected and their Nationality')
plt.xlabel('Count of people affected', fontsize=12)
plt.ylabel('Nationality', fontsize=12)
plt.show()

# %% [markdown]
# > We can see from above graph that 'India' and 'Indian' are same nationality. We can replace 'Indian' with 'India'

# %%
data['Nationality']=data['Nationality'].replace('Indian','India')

# %%
data['Nationality'].value_counts()
# Out:
# India             309
# Italy              18
# Indonesia          10
# United Kingdom      7
# Phillipines         2
# Thailand            2
# Canada              1
# Name: Nationality, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.barplot(data['Nationality'].value_counts().values,data['Nationality'].value_counts().index, palette=sns.dark_palette("blue", reverse=True))
plt.title('Count of people affected and their Nationality')
plt.xlabel('Count of people affected', fontsize=12)
plt.ylabel('Nationality', fontsize=12)
plt.show()

# %% [markdown]
# > Graph between gender and count of affected people.

# %%
plt.figure(figsize=(6,5))
sns.barplot(data['Gender'].value_counts().index,data['Gender'].value_counts().values, palette=sns.dark_palette("blue", reverse=True))
plt.title('Count of people affected and their Gender')
plt.ylabel('Count of people affected', fontsize=12)
plt.xlabel('Gender', fontsize=12)
plt.show()

# %% [markdown]
# > Graph between different states and number of detected cases.

# %%
plt.figure(figsize=(10,10))
sns.barplot(data['Detected state'].value_counts().values,data['Detected state'].value_counts().index, palette=sns.dark_palette("blue", reverse=True))
plt.title('Detected Cases in different states of India.')
plt.xlabel('Count of people affected', fontsize=12)
plt.ylabel('State', fontsize=12)
plt.show()

# %% [markdown]
# > Graph displaying status and count of affected people.

# %%
plt.figure(figsize=(5,5))
sns.barplot(data['Current status'].value_counts().index,data['Current status'].value_counts().values, palette=sns.dark_palette("blue", reverse=True))
plt.title('Status of affected people.')
plt.xlabel('Status', fontsize=12)
plt.ylabel('Count of people affected', fontsize=12)
plt.show()

# %%
plt.figure(figsize=(25,20))
sns.barplot(data['Detected district'].value_counts()[:10].values,data['Detected district'].value_counts()[:10].index, palette=sns.dark_palette("blue", reverse=True))
plt.title('Count of detected cases in top 10 different districst of India.',fontsize=20)
plt.xlabel('Count of people detected', fontsize=12)
plt.ylabel('District', fontsize=20)
plt.rc('xtick',labelsize=25)
plt.rc('ytick',labelsize=25)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.barplot(data['Diagnosed date'].value_counts().values,data['Diagnosed date'].value_counts().index, palette=sns.dark_palette("blue", reverse=True))
plt.title('Date and count of detected cases.')
plt.xlabel('Count of cases detected.', fontsize=12)
plt.ylabel('Detected Dates', fontsize=12)
plt.rc('xtick',labelsize=10)
plt.rc('ytick',labelsize=10)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.swarmplot(data['Current status'],data['Age'],palette=sns.dark_palette("blue", reverse=True))

# %% [markdown]
# > ! This graph shows that the majority of people of hospitalized are in the age group of 20 - 79, and the deceased are the ones in the age group 60 - 80.

# %% [markdown]
# #### No. of days between change in status

# %%
data.head()
# Out:
#    Government id Diagnosed date   Age   Gender             Detected city  \
# ID
# 1       KL-TS-P1     2020-01-30  20.0   Female                  Thrissur
# 2       KL-AL-P1     2020-02-02   NaN  Unknown                 Alappuzha
# 3       KL-KS-P1     2020-02-03   NaN  Unknown                 Kasargode
# 4          DL-P1     2020-03-02  45.0     Male  East Delhi (Mayur Vihar)
# 5          TS-P1     2020-03-02   NaN  Unknown                 Hyderabad
#
#                                   Detected city pt Detected district  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
# 2    SRID=4326;POINT (76.333482 9.498000100000001)         Alappuzha
# 3                          SRID=4326;POINT (80 20)         Kasaragod
# 4                          SRID=4326;POINT (80 20)        East Delhi
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)         Hyderabad
#
#    Detected state Nationality Current status Status change date  \
# ID
# 1          Kerala       India      Recovered         02/14/2020
# 2          Kerala       India      Recovered         02/14/2020
# 3          Kerala       India      Recovered         02/14/2020
# 4           Delhi       India      Recovered         03/15/2020
# 5       Telangana       India      Recovered         03/02/2020
#
#                                                 Notes Current location  \
# ID
# 1           Travelled from Wuhan.\nStudent from Wuhan             None
# 2           Travelled from Wuhan.\nStudent from Wuhan             None
# 3           Travelled from Wuhan.\nStudent from Wuhan             None
# 4   Travelled from Austria, Italy.\nTravel history...             None
# 5   Travelled from Dubai, Singapore contact.\nTrav...             None
#
#                                Current location pt             Created on  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
# 2    SRID=4326;POINT (76.333482 9.498000100000001)  03/23/2020 12:20 p.m.
# 3                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 4                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)  03/23/2020 12:20 p.m.
#
#                Updated on                                           Contacts  \
# ID
# 1   03/23/2020 12:20 p.m.                                               None
# 2   03/23/2020 12:20 p.m.                                               None
# 3   03/23/2020 12:20 p.m.                                               None
# 4   03/23/2020 12:20 p.m.  Patient 22:, Patient 23:, Patient 24:, Patient...
# 5   03/23/2020 12:20 p.m.                                               None
#
#    status change difference
# ID
# 1                   15 days
# 2                   12 days
# 3                   11 days
# 4                   13 days
# 5                    0 days

# %% [markdown]
# #### Days taken to change status(Hospitalized/Death/Recover)

# %%
data['status change difference'] = pd.to_datetime(data['Status change date'])-pd.to_datetime(data['Diagnosed date'])

# %%
data['status change difference'].astype('str')
# Out:
# ID
# 1        15 days 00:00:00.000000000
# 2        12 days 00:00:00.000000000
# 3        11 days 00:00:00.000000000
# 4        13 days 00:00:00.000000000
# 5         0 days 00:00:00.000000000
#                    ...
# 500    -29 days +00:00:00.000000000
# 501    -29 days +00:00:00.000000000
# 502    -29 days +00:00:00.000000000
# 503    -29 days +00:00:00.000000000
# 504    -29 days +00:00:00.000000000
# Name: status change difference, Length: 504, dtype: object

# %%
data.tail()
# Out:
#     Government id Diagnosed date   Age Gender Detected city  \
# ID
# 500          None     2020-03-23  25.0   Male       Chennai
# 501          None     2020-03-23  48.0   Male      Tiruppur
# 502          None     2020-03-23  54.0   Male       Madurai
# 503          None     2020-03-23  24.0   Male          None
# 504          None     2020-03-23  35.0   Male       Jaunpur
#
#                                       Detected city pt Detected district  \
# ID
# 500            SRID=4326;POINT (80.2838331 13.0801721)           Chennai
# 501    SRID=4326;POINT (77.52604780096844 10.78322705)          Tiruppur
# 502  SRID=4326;POINT (78.11409829999999 9.926115299...           Madurai
# 503             SRID=4326;POINT (85.906508 25.6440845)             Patna
# 504     SRID=4326;POINT (82.48834097504385 25.7955927)          Varanasi
#
#     Detected state Nationality Current status Status change date  \
# ID
# 500     Tamil Nadu        None   Hospitalized         02/23/2020
# 501     Tamil Nadu        None   Hospitalized         02/23/2020
# 502     Tamil Nadu        None   Hospitalized         02/23/2020
# 503          Bihar        None   Hospitalized         02/23/2020
# 504  Uttar Pradesh        None   Hospitalized         02/23/2020
#
#                                                  Notes Current location  \
# ID
# 500                       Travelled from London - RGGH             None
# 501                        Travelled from London - ESI             None
# 502  Annanagar at Rajaji Hosp. No mention of travel...             None
# 503                            Travelled from Scotland             None
# 504  Travelled from Saudi Arabia on 15th Mar; Sympt...             None
#
#                                    Current location pt            Created on  \
# ID
# 500            SRID=4326;POINT (80.2838331 13.0801721)  03/24/2020 8:15 a.m.
# 501    SRID=4326;POINT (77.52604780096844 10.78322705)  03/24/2020 8:15 a.m.
# 502  SRID=4326;POINT (78.11409829999999 9.926115299...  03/24/2020 8:15 a.m.
# 503             SRID=4326;POINT (85.906508 25.6440845)  03/24/2020 8:15 a.m.
# 504     SRID=4326;POINT (82.48834097504385 25.7955927)  03/24/2020 8:15 a.m.
#
#                Updated on Contacts status change difference
# ID
# 500  03/24/2020 8:15 a.m.     None                 -29 days
# 501  03/24/2020 8:15 a.m.     None                 -29 days
# 502  03/24/2020 8:15 a.m.     None                 -29 days
# 503  03/24/2020 8:15 a.m.     None                 -29 days
# 504  03/24/2020 8:15 a.m.     None                 -29 days

# %%
pd.to_datetime(data['Diagnosed date'])
# Out:
# ID
# 1     2020-01-30
# 2     2020-02-02
# 3     2020-02-03
# 4     2020-03-02
# 5     2020-03-02
#          ...
# 500   2020-03-23
# 501   2020-03-23
# 502   2020-03-23
# 503   2020-03-23
# 504   2020-03-23
# Name: Diagnosed date, Length: 504, dtype: datetime64[ns]

# %%
pd.to_datetime(data['Status change date'])
# Out:
# ID
# 1     2020-02-14
# 2     2020-02-14
# 3     2020-02-14
# 4     2020-03-15
# 5     2020-03-02
#          ...
# 500   2020-02-23
# 501   2020-02-23
# 502   2020-02-23
# 503   2020-02-23
# 504   2020-02-23
# Name: Status change date, Length: 504, dtype: datetime64[ns]

# %%
data['status change difference'].value_counts()
# Out:
# 0 days      389
# -29 days    102
# 1 days        3
# 8 days        2
# 3 days        1
# 9 days        1
# 12 days       1
# 15 days       1
# 10 days       1
# 13 days       1
# 2 days        1
# 11 days       1
# Name: status change difference, dtype: int64

# %% [markdown]
# ### As we can see that many of the dates in the 'Status Change Date' are incorrect due to which the status change difference comes out to be negative.

# %% [markdown]
# ---

# %%
data.drop('status change difference',axis=1,inplace=True
         )

# %%
data.head()
# Out:
#    Government id Diagnosed date   Age   Gender             Detected city  \
# ID
# 1       KL-TS-P1     2020-01-30  20.0   Female                  Thrissur
# 2       KL-AL-P1     2020-02-02   NaN  Unknown                 Alappuzha
# 3       KL-KS-P1     2020-02-03   NaN  Unknown                 Kasargode
# 4          DL-P1     2020-03-02  45.0     Male  East Delhi (Mayur Vihar)
# 5          TS-P1     2020-03-02   NaN  Unknown                 Hyderabad
#
#                                   Detected city pt Detected district  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
# 2    SRID=4326;POINT (76.333482 9.498000100000001)         Alappuzha
# 3                          SRID=4326;POINT (80 20)         Kasaragod
# 4                          SRID=4326;POINT (80 20)        East Delhi
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)         Hyderabad
#
#    Detected state Nationality Current status Status change date  \
# ID
# 1          Kerala       India      Recovered         02/14/2020
# 2          Kerala       India      Recovered         02/14/2020
# 3          Kerala       India      Recovered         02/14/2020
# 4           Delhi       India      Recovered         03/15/2020
# 5       Telangana       India      Recovered         03/02/2020
#
#                                                 Notes Current location  \
# ID
# 1           Travelled from Wuhan.\nStudent from Wuhan             None
# 2           Travelled from Wuhan.\nStudent from Wuhan             None
# 3           Travelled from Wuhan.\nStudent from Wuhan             None
# 4   Travelled from Austria, Italy.\nTravel history...             None
# 5   Travelled from Dubai, Singapore contact.\nTrav...             None
#
#                                Current location pt             Created on  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
# 2    SRID=4326;POINT (76.333482 9.498000100000001)  03/23/2020 12:20 p.m.
# 3                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 4                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)  03/23/2020 12:20 p.m.
#
#                Updated on                                           Contacts
# ID
# 1   03/23/2020 12:20 p.m.                                               None
# 2   03/23/2020 12:20 p.m.                                               None
# 3   03/23/2020 12:20 p.m.                                               None
# 4   03/23/2020 12:20 p.m.  Patient 22:, Patient 23:, Patient 24:, Patient...
# 5   03/23/2020 12:20 p.m.                                               None

# %%
data['Transmission info'] = data['Contacts'].apply(lambda x : False if x == None else True)

# %%
data.head()
# Out:
#    Government id Diagnosed date   Age   Gender             Detected city  \
# ID
# 1       KL-TS-P1     2020-01-30  20.0   Female                  Thrissur
# 2       KL-AL-P1     2020-02-02   NaN  Unknown                 Alappuzha
# 3       KL-KS-P1     2020-02-03   NaN  Unknown                 Kasargode
# 4          DL-P1     2020-03-02  45.0     Male  East Delhi (Mayur Vihar)
# 5          TS-P1     2020-03-02   NaN  Unknown                 Hyderabad
#
#                                   Detected city pt Detected district  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)          Thrissur
# 2    SRID=4326;POINT (76.333482 9.498000100000001)         Alappuzha
# 3                          SRID=4326;POINT (80 20)         Kasaragod
# 4                          SRID=4326;POINT (80 20)        East Delhi
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)         Hyderabad
#
#    Detected state Nationality Current status Status change date  \
# ID
# 1          Kerala       India      Recovered         02/14/2020
# 2          Kerala       India      Recovered         02/14/2020
# 3          Kerala       India      Recovered         02/14/2020
# 4           Delhi       India      Recovered         03/15/2020
# 5       Telangana       India      Recovered         03/02/2020
#
#                                                 Notes Current location  \
# ID
# 1           Travelled from Wuhan.\nStudent from Wuhan             None
# 2           Travelled from Wuhan.\nStudent from Wuhan             None
# 3           Travelled from Wuhan.\nStudent from Wuhan             None
# 4   Travelled from Austria, Italy.\nTravel history...             None
# 5   Travelled from Dubai, Singapore contact.\nTrav...             None
#
#                                Current location pt             Created on  \
# ID
# 1   SRID=4326;POINT (76.21325419999999 10.5256264)  03/23/2020 12:20 p.m.
# 2    SRID=4326;POINT (76.333482 9.498000100000001)  03/23/2020 12:20 p.m.
# 3                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 4                          SRID=4326;POINT (80 20)  03/23/2020 12:20 p.m.
# 5    SRID=4326;POINT (78.4349398685041 17.4263524)  03/23/2020 12:20 p.m.
#
#                Updated on                                           Contacts  \
# ID
# 1   03/23/2020 12:20 p.m.                                               None
# 2   03/23/2020 12:20 p.m.                                               None
# 3   03/23/2020 12:20 p.m.                                               None
# 4   03/23/2020 12:20 p.m.  Patient 22:, Patient 23:, Patient 24:, Patient...
# 5   03/23/2020 12:20 p.m.                                               None
#
#     Transmission info
# ID
# 1               False
# 2               False
# 3               False
# 4                True
# 5               False

# %%
data['Transmission info'].value_counts()
# Out:
# False    357
# True     147
# Name: Transmission info, dtype: int64

# %%
plt.title('False if a patient did not spread COVID19 to others else True')
sns.countplot(data['Transmission info'],palette=sns.dark_palette('blue',reverse=True))

# %% [markdown]
# > We can estimate how many people are carriers of COVID19

# %%
print("COVID19 estimated to be spread by {} people".format(data['Transmission info'].value_counts()[1]))
# Out:
# COVID19 estimated to be spread by 147 people

# %%
X = data['Diagnosed date'].value_counts().index
Y = data['Diagnosed date'].value_counts().values

# %%
plt.figure(figsize=(15,5))
sns.lineplot(X,Y)
